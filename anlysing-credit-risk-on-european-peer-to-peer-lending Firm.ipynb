# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/bondora-raw-dataset/Bondora_raw.csv

# %%
# 'Matplotlib' is a data visualization library for 2D and 3D plots, built on numpy
from matplotlib import pyplot as plt
# %matplotlib inline
# 'Seaborn' is based on matplotlib; used for plotting statistical graphics
import seaborn as sns
# to suppress warnings
import warnings
warnings.filterwarnings("ignore")

# %%
Bondora = pd.read_csv("../input/bondora-raw-dataset/Bondora_raw.csv", index_col="LoanNumber")

# %%
Bondora.head()
# Out:
#            ReportAsOfEOD                                LoanId  \
# LoanNumber
# 659           2020-01-27  F0660C80-83F3-4A97-8DA0-9C250112D6EC
# 654           2020-01-27  978BB85B-1C69-4D51-8447-9C240104A3A2
# 641           2020-01-27  EA44027E-7FA7-4BB2-846D-9C1F013C8A22
# 668           2020-01-27  CE67AD25-2951-4BEE-96BD-9C2700C61EF4
# 652           2020-01-27  9408BF8C-B159-4D6A-9D61-9C2400A986E3
#
#                     ListedOnUTC     BiddingStartedOn  BidsPortfolioManager  \
# LoanNumber
# 659         2009-06-11 16:40:39  2009-06-11 16:40:39                     0
# 654         2009-06-10 15:48:57  2009-06-10 15:48:57                     0
# 641         2009-06-05 19:12:29  2009-06-05 19:12:29                     0
# 668         2009-06-13 12:01:20  2009-06-13 12:01:20                     0
# 652         2009-06-10 10:17:13  2009-06-10 10:17:13                     0
#
#             BidsApi  BidsManual  UserName  NewCreditCustomer  \
# LoanNumber
# 659               0    115.0410      KARU               True
# 654               0    140.6057  koort681              False
# 641               0    319.5580       0ie               True
# 668               0     57.5205    Alyona               True
# 652               0    319.5582       Kai               True
#
#            LoanApplicationStartedDate  ...  \
# LoanNumber                             ...
# 659               2009-06-11 16:40:39  ...
# 654               2009-06-10 15:48:57  ...
# 641               2009-06-05 19:12:29  ...
# 668               2009-06-13 12:01:20  ...
# 652               2009-06-10 10:17:13  ...
#
#            PreviousEarlyRepaymentsCountBeforeLoan GracePeriodStart  \
# LoanNumber
# 659                                             0              NaN
# 654                                             0              NaN
# 641                                             0              NaN
# 668                                             0              NaN
# 652                                             0              NaN
#
#            GracePeriodEnd NextPaymentDate NextPaymentNr  \
# LoanNumber
# 659                   NaN             NaN           NaN
# 654                   NaN             NaN           NaN
# 641                   NaN             NaN           NaN
# 668                   NaN             NaN           NaN
# 652                   NaN             NaN           NaN
#
#             NrOfScheduledPayments  ReScheduledOn  PrincipalDebtServicingCost  \
# LoanNumber
# 659                           NaN            NaN                         0.0
# 654                           NaN            NaN                         0.0
# 641                           NaN            NaN                         0.0
# 668                           NaN            NaN                         0.0
# 652                           NaN            NaN                         0.0
#
#             InterestAndPenaltyDebtServicingCost  ActiveLateLastPaymentCategory
# LoanNumber
# 659                                         0.0                            NaN
# 654                                         0.0                            NaN
# 641                                         0.0                           180+
# 668                                         0.0                            NaN
# 652                                         0.0                           180+
#
# [5 rows x 111 columns]

# %%
Bondora.shape
# Out:
# (134529, 111)

# %%
Bondora.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134529 entries, 659 to 285630
# Columns: 111 entries, ReportAsOfEOD to ActiveLateLastPaymentCategory
# dtypes: bool(3), float64(56), int64(13), object(39)
# memory usage: 112.3+ MB

# %%
list(Bondora.dtypes)
# Out:
# [dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('bool'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('bool'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('bool'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O')]

# %%
# Summary Statistics for Numerical data:

Bondora.describe()
# Out:
#        BidsPortfolioManager        BidsApi     BidsManual  \
# count         134529.000000  134529.000000  134529.000000
# mean             966.452876      29.111664     559.332590
# std             1355.686016     150.159148     750.360512
# min                0.000000       0.000000       0.000000
# 25%              155.000000       0.000000      96.000000
# 50%              465.000000       0.000000     317.000000
# 75%             1218.000000       5.000000     729.000000
# max            10625.000000    7570.000000   10630.000000
#
#        ApplicationSignedHour  ApplicationSignedWeekday  VerificationType  \
# count          134529.000000             134529.000000     134484.000000
# mean               13.374640                  3.907908          2.817257
# std                 4.992375                  1.726192          1.407908
# min                 0.000000                  1.000000          0.000000
# 25%                10.000000                  2.000000          1.000000
# 50%                13.000000                  4.000000          4.000000
# 75%                17.000000                  5.000000          4.000000
# max                23.000000                  7.000000          4.000000
#
#         LanguageCode            Age         Gender  AppliedAmount  ...  \
# count  134529.000000  134529.000000  134484.000000  134529.000000  ...
# mean        2.827874      40.819295       0.442097    2727.947540  ...
# std         1.959802      12.348693       0.636083    2374.439168  ...
# min         1.000000       0.000000       0.000000      31.955800  ...
# 25%         1.000000      31.000000       0.000000     800.000000  ...
# 50%         3.000000      40.000000       0.000000    2125.000000  ...
# 75%         4.000000      50.000000       1.000000    4145.000000  ...
# max        22.000000      77.000000       2.000000   10632.000000  ...
#
#        InterestAndPenaltyBalance  NoOfPreviousLoansBeforeLoan  \
# count              134529.000000                134529.000000
# mean                  701.567107                     1.487620
# std                  2514.595572                     2.396148
# min                    -2.660000                     0.000000
# 25%                     0.000000                     0.000000
# 50%                     0.000000                     1.000000
# 75%                   202.900000                     2.000000
# max                 64494.770000                    25.000000
#
#        AmountOfPreviousLoansBeforeLoan  PreviousRepaymentsBeforeLoan  \
# count                    134529.000000                  91368.000000
# mean                       2868.652401                    928.395548
# std                        4507.046575                   2042.348751
# min                           0.000000                      0.000000
# 25%                           0.000000                      0.000000
# 50%                         396.354100                    197.980000
# 75%                        4250.000000                    780.950000
# max                       53762.000000                  34077.420000
#
#        PreviousEarlyRepaymentsBefoleLoan  \
# count                       58026.000000
# mean                          320.743805
# std                          1561.799076
# min                             0.000000
# 25%                             0.000000
# 50%                             0.000000
# 75%                             0.000000
# max                         48100.000000
#
#        PreviousEarlyRepaymentsCountBeforeLoan  NextPaymentNr  \
# count                           134529.000000   97788.000000
# mean                                 0.069903       5.178795
# std                                  0.359461       7.674427
# min                                  0.000000       0.000000
# 25%                                  0.000000       0.000000
# 50%                                  0.000000       3.000000
# 75%                                  0.000000       7.000000
# max                                 11.000000      60.000000
#
#        NrOfScheduledPayments  PrincipalDebtServicingCost  \
# count           97788.000000                59129.000000
# mean               50.126795                    5.264702
# std                12.519530                   57.800582
# min                 1.000000                    0.000000
# 25%                36.000000                    0.000000
# 50%                60.000000                    0.000000
# 75%                60.000000                    0.000000
# max                72.000000                 3325.330000
#
#        InterestAndPenaltyDebtServicingCost
# count                         59129.000000
# mean                             89.851455
# std                             287.449052
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                              17.330000
# max                            5295.290000
#
# [8 rows x 69 columns]

# %%
# Summary Statistics for Categorical data:

Bondora.describe(exclude=[np.number])
# Out:
#        ReportAsOfEOD                                LoanId  \
# count         134529                                134529
# unique             1                                134529
# top       2020-01-27  F0660C80-83F3-4A97-8DA0-9C250112D6EC
# freq          134529                                     1
#
#                 ListedOnUTC     BiddingStartedOn UserName NewCreditCustomer  \
# count                134529               134529   134529            134529
# unique               134130               134135    66654                 2
# top     2017-04-20 09:54:00  2017-04-20 12:54:00     eiks              True
# freq                      4                    4       26             77808
#
#        LoanApplicationStartedDate    LoanDate ContractEndDate  \
# count                      134529      134529           58983
# unique                     134334        3502            3944
# top           2019-04-11 17:08:54  2019-10-15      2024-12-27
# freq                            4         455             622
#
#        FirstPaymentDate  ... ActiveLateCategory WorseLateCategory  \
# count            134529  ...              48518             89073
# unique             2138  ...                  9                 9
# top          2019-11-04  ...               180+              180+
# freq               2030  ...              32859             34789
#
#        CreditScoreEsMicroL CreditScoreEsEquifaxRisk  \
# count               104955                    12219
# unique                  11                        6
# top                      M                        B
# freq                 92439                     6596
#
#        CreditScoreFiAsiakasTietoRiskGrade GracePeriodStart GracePeriodEnd  \
# count                               32518            18788          18788
# unique                                 21              991           1239
# top                                     3       2019-12-27     2020-04-27
# freq                                10543              458            348
#
#        NextPaymentDate ReScheduledOn ActiveLateLastPaymentCategory
# count            65644         40322                         52250
# unique              26          1700                             9
# top         2020-02-10    2020-01-13                          180+
# freq             11714           291                         24449
#
# [4 rows x 42 columns]

# %% [markdown]
# ### 6. Missing Values¶

# %%
Bondora.isna().sum()
# Out:
# ReportAsOfEOD                              0
# LoanId                                     0
# ListedOnUTC                                0
# BiddingStartedOn                           0
# BidsPortfolioManager                       0
#                                        ...
# NrOfScheduledPayments                  36741
# ReScheduledOn                          94207
# PrincipalDebtServicingCost             75400
# InterestAndPenaltyDebtServicingCost    75400
# ActiveLateLastPaymentCategory          82279
# Length: 111, dtype: int64

# %%
Bondora1 = Bondora.dropna(axis=1)

# %%
Bondora1
# Out:
#            ReportAsOfEOD                                LoanId  \
# LoanNumber
# 659           2020-01-27  F0660C80-83F3-4A97-8DA0-9C250112D6EC
# 654           2020-01-27  978BB85B-1C69-4D51-8447-9C240104A3A2
# 641           2020-01-27  EA44027E-7FA7-4BB2-846D-9C1F013C8A22
# 668           2020-01-27  CE67AD25-2951-4BEE-96BD-9C2700C61EF4
# 652           2020-01-27  9408BF8C-B159-4D6A-9D61-9C2400A986E3
# ...                  ...                                   ...
# 283484        2020-01-27  A9C9EF0F-4E79-4930-BA8A-A4130077FCC2
# 285168        2020-01-27  787345C2-7606-4F72-8FE2-A4170082D77C
# 281602        2020-01-27  E2D3384D-289A-4B4D-A2DA-A40F00F7C755
# 285431        2020-01-27  7CC7AB74-995B-4467-958A-A41700F78D59
# 285630        2020-01-27  3A0DEBF3-292C-4EB4-B71A-A4170157749D
#
#                     ListedOnUTC     BiddingStartedOn  BidsPortfolioManager  \
# LoanNumber
# 659         2009-06-11 16:40:39  2009-06-11 16:40:39                     0
# 654         2009-06-10 15:48:57  2009-06-10 15:48:57                     0
# 641         2009-06-05 19:12:29  2009-06-05 19:12:29                     0
# 668         2009-06-13 12:01:20  2009-06-13 12:01:20                     0
# 652         2009-06-10 10:17:13  2009-06-10 10:17:13                     0
# ...                         ...                  ...                   ...
# 283484      2015-01-02 16:31:36  2015-01-02 16:31:36                  2515
# 285168      2015-01-05 16:14:26  2015-01-05 16:14:26                  1880
# 281602      2015-01-02 14:04:27  2015-01-02 14:04:27                  1975
# 285431      2015-01-05 16:56:12  2015-01-05 16:56:12                  1840
# 285630      2015-01-06 11:07:06  2015-01-06 11:07:06                  2990
#
#             BidsApi  BidsManual   UserName  NewCreditCustomer  \
# LoanNumber
# 659               0    115.0410       KARU               True
# 654               0    140.6057   koort681              False
# 641               0    319.5580        0ie               True
# 668               0     57.5205     Alyona               True
# 652               0    319.5582        Kai               True
# ...             ...         ...        ...                ...
# 283484            0    485.0000  BO73K5A6A               True
# 285168            0   1120.0000   BO311A49              False
# 281602            0    525.0000  BO41K639A               True
# 285431            0   1160.0000   BO45A925              False
# 285630            0     10.0000  BO152923A              False
#
#            LoanApplicationStartedDate  ... ActiveScheduleFirstPaymentReached  \
# LoanNumber                             ...
# 659               2009-06-11 16:40:39  ...                              True
# 654               2009-06-10 15:48:57  ...                              True
# 641               2009-06-05 19:12:29  ...                              True
# 668               2009-06-13 12:01:20  ...                              True
# 652               2009-06-10 10:17:13  ...                              True
# ...                               ...  ...                               ...
# 283484            2015-01-01 07:17:03  ...                              True
# 285168            2015-01-05 07:56:22  ...                              True
# 281602            2014-12-28 15:01:47  ...                              True
# 285431            2015-01-05 15:01:18  ...                              True
# 285630            2015-01-05 20:50:24  ...                              True
#
#             Status Restructured PrincipalPaymentsMade  \
# LoanNumber
# 659         Repaid        False              115.0408
# 654         Repaid        False              140.6057
# 641           Late         True              203.1909
# 668         Repaid        False               57.5205
# 652         Repaid        False              319.5436
# ...            ...          ...                   ...
# 283484      Repaid        False             2308.1900
# 285168      Repaid        False             3000.0000
# 281602        Late        False             1869.7600
# 285431      Repaid         True             2257.5400
# 285630        Late         True             1473.9100
#
#             InterestAndPenaltyPaymentsMade  PrincipalBalance  \
# LoanNumber
# 659                                20.4222              0.00
# 654                                 2.0227              0.00
# 641                                59.7626            116.35
# 668                                18.7323              0.00
# 652                               220.4200              0.00
# ...                                    ...               ...
# 283484                              0.0000              0.00
# 285168                           1990.0300              0.00
# 281602                            199.3300            630.24
# 285431                            561.5300              0.00
# 285630                            683.2100           1526.09
#
#             InterestAndPenaltyBalance  NoOfPreviousLoansBeforeLoan  \
# LoanNumber
# 659                              0.00                            1
# 654                              0.00                            2
# 641                            414.07                            0
# 668                              0.00                            1
# 652                              0.00                            1
# ...                               ...                          ...
# 283484                           0.00                            0
# 285168                           0.00                            1
# 281602                        1227.98                            0
# 285431                           0.00                            1
# 285630                        9019.04                            1
#
#            AmountOfPreviousLoansBeforeLoan  \
# LoanNumber
# 659                                83.0852
# 654                               255.6467
# 641                                 0.0000
# 668                               134.2144
# 652                               146.9966
# ...                                    ...
# 283484                              0.0000
# 285168                           3000.0000
# 281602                              0.0000
# 285431                            500.0000
# 285630                           2500.0000
#
#            PreviousEarlyRepaymentsCountBeforeLoan
# LoanNumber
# 659                                             0
# 654                                             0
# 641                                             0
# 668                                             0
# 652                                             0
# ...                                           ...
# 283484                                          0
# 285168                                          0
# 281602                                          0
# 285431                                          0
# 285630                                          0
#
# [134529 rows x 47 columns]

# %%
print(Bondora1.describe().transpose())
# Out:
#                                            count         mean           std  \
# BidsPortfolioManager                    134529.0   966.452876   1355.686016
# BidsApi                                 134529.0    29.111664    150.159148
# BidsManual                              134529.0   559.332590    750.360512
# ApplicationSignedHour                   134529.0    13.374640      4.992375
# ApplicationSignedWeekday                134529.0     3.907908      1.726192
# LanguageCode                            134529.0     2.827874      1.959802
# Age                                     134529.0    40.819295     12.348693
# AppliedAmount                           134529.0  2727.947540   2374.439168
# Amount                                  134529.0  2543.872472   2170.128183
# Interest                                134529.0    35.889583     26.288644
# LoanDuration                            134529.0    46.151573     15.202688
# UseOfLoan                               134529.0     0.343026      3.311925
# IncomeFromPrincipalEmployer             134529.0   437.143384   1786.569939
# IncomeFromPension                       134529.0    18.802698    150.849487
# IncomeFromFamilyAllowance               134529.0     5.682848     38.385899
# IncomeFromSocialWelfare                 134529.0     2.390005     36.791193
# IncomeFromLeavePay                      134529.0     3.253239     77.523767
# IncomeFromChildSupport                  134529.0     2.359142     28.459953
# IncomeOther                             134529.0    43.112825    459.081430
# IncomeTotal                             134529.0  1724.150015   4970.165757
# ExistingLiabilities                     134529.0     3.181797      3.424242
# LiabilitiesTotal                        134529.0   562.027010  33831.634630
# RefinanceLiabilities                    134529.0     0.187313      0.896455
# MonthlyPaymentDay                       134529.0    11.143188      7.044104
# PrincipalPaymentsMade                   134529.0   761.476162   1371.557801
# InterestAndPenaltyPaymentsMade          134529.0   488.397102    827.805133
# PrincipalBalance                        134529.0  1769.281104   2030.546309
# InterestAndPenaltyBalance               134529.0   701.567107   2514.595572
# NoOfPreviousLoansBeforeLoan             134529.0     1.487620      2.396148
# AmountOfPreviousLoansBeforeLoan         134529.0  2868.652401   4507.046575
# PreviousEarlyRepaymentsCountBeforeLoan  134529.0     0.069903      0.359461
#
#                                             min     25%        50%      75%  \
# BidsPortfolioManager                     0.0000  155.00   465.0000  1218.00
# BidsApi                                  0.0000    0.00     0.0000     5.00
# BidsManual                               0.0000   96.00   317.0000   729.00
# ApplicationSignedHour                    0.0000   10.00    13.0000    17.00
# ApplicationSignedWeekday                 1.0000    2.00     4.0000     5.00
# LanguageCode                             1.0000    1.00     3.0000     4.00
# Age                                      0.0000   31.00    40.0000    50.00
# AppliedAmount                           31.9558  800.00  2125.0000  4145.00
# Amount                                   6.3900  744.00  2125.0000  3600.00
# Interest                                 3.0000   20.00    30.9300    40.40
# LoanDuration                             1.0000   36.00    48.0000    60.00
# UseOfLoan                               -1.0000   -1.00    -1.0000     0.00
# IncomeFromPrincipalEmployer              0.0000    0.00     0.0000   326.00
# IncomeFromPension                        0.0000    0.00     0.0000     0.00
# IncomeFromFamilyAllowance                0.0000    0.00     0.0000     0.00
# IncomeFromSocialWelfare                  0.0000    0.00     0.0000     0.00
# IncomeFromLeavePay                       0.0000    0.00     0.0000     0.00
# IncomeFromChildSupport                   0.0000    0.00     0.0000     0.00
# IncomeOther                              0.0000    0.00     0.0000     0.00
# IncomeTotal                              0.0000  857.00  1250.0000  1900.00
# ExistingLiabilities                      0.0000    1.00     2.0000     5.00
# LiabilitiesTotal                         0.0000   73.54   316.3800   620.58
# RefinanceLiabilities                     0.0000    0.00     0.0000     0.00
# MonthlyPaymentDay                        0.0000    5.00    10.0000    15.00
# PrincipalPaymentsMade                    0.0000   50.87   208.1000   766.41
# InterestAndPenaltyPaymentsMade           0.0000   44.93   181.2100   568.53
# PrincipalBalance                       -34.2000  212.82  1061.9900  2636.33
# InterestAndPenaltyBalance               -2.6600    0.00     0.0000   202.90
# NoOfPreviousLoansBeforeLoan              0.0000    0.00     1.0000     2.00
# AmountOfPreviousLoansBeforeLoan          0.0000    0.00   396.3541  4250.00
# PreviousEarlyRepaymentsCountBeforeLoan   0.0000    0.00     0.0000     0.00
#
#                                                 max
# BidsPortfolioManager                       10625.00
# BidsApi                                     7570.00
# BidsManual                                 10630.00
# ApplicationSignedHour                         23.00
# ApplicationSignedWeekday                       7.00
# LanguageCode                                  22.00
# Age                                           77.00
# AppliedAmount                              10632.00
# Amount                                     10632.00
# Interest                                     264.31
# LoanDuration                                  60.00
# UseOfLoan                                    110.00
# IncomeFromPrincipalEmployer               228400.00
# IncomeFromPension                           5038.00
# IncomeFromFamilyAllowance                   2006.00
# IncomeFromSocialWelfare                     4551.00
# IncomeFromLeavePay                         21300.00
# IncomeFromChildSupport                      2500.00
# IncomeOther                                50000.00
# IncomeTotal                              1012019.00
# ExistingLiabilities                           40.00
# LiabilitiesTotal                        12400000.00
# RefinanceLiabilities                          23.00
# MonthlyPaymentDay                             28.00
# PrincipalPaymentsMade                      10632.00
# InterestAndPenaltyPaymentsMade             16873.00
# PrincipalBalance                           10632.00
# InterestAndPenaltyBalance                  64494.77
# NoOfPreviousLoansBeforeLoan                   25.00
# AmountOfPreviousLoansBeforeLoan            53762.00
# PreviousEarlyRepaymentsCountBeforeLoan        11.00

# %%
Bondora1.shape
# Out:
# (134529, 47)

# %%
Bondora1.dtypes
# Out:
# ReportAsOfEOD                              object
# LoanId                                     object
# ListedOnUTC                                object
# BiddingStartedOn                           object
# BidsPortfolioManager                        int64
# BidsApi                                     int64
# BidsManual                                float64
# UserName                                   object
# NewCreditCustomer                            bool
# LoanApplicationStartedDate                 object
# LoanDate                                   object
# FirstPaymentDate                           object
# MaturityDate_Original                      object
# MaturityDate_Last                          object
# ApplicationSignedHour                       int64
# ApplicationSignedWeekday                    int64
# LanguageCode                                int64
# Age                                         int64
# DateOfBirth                                object
# Country                                    object
# AppliedAmount                             float64
# Amount                                    float64
# Interest                                  float64
# LoanDuration                                int64
# UseOfLoan                                   int64
# IncomeFromPrincipalEmployer               float64
# IncomeFromPension                         float64
# IncomeFromFamilyAllowance                 float64
# IncomeFromSocialWelfare                   float64
# IncomeFromLeavePay                        float64
# IncomeFromChildSupport                    float64
# IncomeOther                               float64
# IncomeTotal                               float64
# ExistingLiabilities                         int64
# LiabilitiesTotal                          float64
# RefinanceLiabilities                        int64
# MonthlyPaymentDay                           int64
# ActiveScheduleFirstPaymentReached            bool
# Status                                     object
# Restructured                                 bool
# PrincipalPaymentsMade                     float64
# InterestAndPenaltyPaymentsMade            float64
# PrincipalBalance                          float64
# InterestAndPenaltyBalance                 float64
# NoOfPreviousLoansBeforeLoan                 int64
# AmountOfPreviousLoansBeforeLoan           float64
# PreviousEarlyRepaymentsCountBeforeLoan      int64
# dtype: object

# %%
names = Bondora1.columns

# %% [markdown]
# ### Object and bool data types

# %%
categorical_data= Bondora1.select_dtypes('object') 
Bondora1 = Bondora1.drop(categorical_data.columns, axis=1)
booleen_data= Bondora1.select_dtypes('bool')
Bondora1 = Bondora1.drop(booleen_data.columns, axis=1)

# %%
categorical_data
# Out:
#            ReportAsOfEOD                                LoanId  \
# LoanNumber
# 659           2020-01-27  F0660C80-83F3-4A97-8DA0-9C250112D6EC
# 654           2020-01-27  978BB85B-1C69-4D51-8447-9C240104A3A2
# 641           2020-01-27  EA44027E-7FA7-4BB2-846D-9C1F013C8A22
# 668           2020-01-27  CE67AD25-2951-4BEE-96BD-9C2700C61EF4
# 652           2020-01-27  9408BF8C-B159-4D6A-9D61-9C2400A986E3
# ...                  ...                                   ...
# 283484        2020-01-27  A9C9EF0F-4E79-4930-BA8A-A4130077FCC2
# 285168        2020-01-27  787345C2-7606-4F72-8FE2-A4170082D77C
# 281602        2020-01-27  E2D3384D-289A-4B4D-A2DA-A40F00F7C755
# 285431        2020-01-27  7CC7AB74-995B-4467-958A-A41700F78D59
# 285630        2020-01-27  3A0DEBF3-292C-4EB4-B71A-A4170157749D
#
#                     ListedOnUTC     BiddingStartedOn   UserName  \
# LoanNumber
# 659         2009-06-11 16:40:39  2009-06-11 16:40:39       KARU
# 654         2009-06-10 15:48:57  2009-06-10 15:48:57   koort681
# 641         2009-06-05 19:12:29  2009-06-05 19:12:29        0ie
# 668         2009-06-13 12:01:20  2009-06-13 12:01:20     Alyona
# 652         2009-06-10 10:17:13  2009-06-10 10:17:13        Kai
# ...                         ...                  ...        ...
# 283484      2015-01-02 16:31:36  2015-01-02 16:31:36  BO73K5A6A
# 285168      2015-01-05 16:14:26  2015-01-05 16:14:26   BO311A49
# 281602      2015-01-02 14:04:27  2015-01-02 14:04:27  BO41K639A
# 285431      2015-01-05 16:56:12  2015-01-05 16:56:12   BO45A925
# 285630      2015-01-06 11:07:06  2015-01-06 11:07:06  BO152923A
#
#            LoanApplicationStartedDate    LoanDate FirstPaymentDate  \
# LoanNumber
# 659               2009-06-11 16:40:39  2009-06-16       2009-07-27
# 654               2009-06-10 15:48:57  2009-06-15       2009-07-15
# 641               2009-06-05 19:12:29  2009-06-15       2009-07-27
# 668               2009-06-13 12:01:20  2009-06-15       2009-07-15
# 652               2009-06-10 10:17:13  2009-06-14       2009-07-27
# ...                               ...         ...              ...
# 283484            2015-01-01 07:17:03  2015-01-06       2015-03-02
# 285168            2015-01-05 07:56:22  2015-01-06       2015-03-05
# 281602            2014-12-28 15:01:47  2015-01-06       2015-03-02
# 285431            2015-01-05 15:01:18  2015-01-06       2015-03-02
# 285630            2015-01-05 20:50:24  2015-01-06       2015-03-03
#
#            MaturityDate_Original MaturityDate_Last DateOfBirth Country  Status
# LoanNumber
# 659                   2010-06-25        2010-06-25  1947-11-26      EE  Repaid
# 654                   2009-07-15        2009-07-15  1960-11-05      EE  Repaid
# 641                   2011-02-25        2014-05-13  1950-11-13      EE    Late
# 668                   2010-09-15        2010-09-15  1986-03-29      EE  Repaid
# 652                   2010-06-25        2010-06-25  1983-09-30      EE  Repaid
# ...                          ...               ...         ...     ...     ...
# 283484                2020-02-03        2020-02-03  1977-02-07      FI  Repaid
# 285168                2020-02-05        2019-02-20  1979-05-17      FI  Repaid
# 281602                2020-02-03        2020-02-03  1974-01-25      FI    Late
# 285431                2020-02-03        2020-08-03  1967-01-28      EE  Repaid
# 285630                2020-02-03        2020-08-12  1993-09-30      EE    Late
#
# [134529 rows x 13 columns]

# %%
booleen_data
# Out:
#             NewCreditCustomer  ActiveScheduleFirstPaymentReached  Restructured
# LoanNumber
# 659                      True                               True         False
# 654                     False                               True         False
# 641                      True                               True          True
# 668                      True                               True         False
# 652                      True                               True         False
# ...                       ...                                ...           ...
# 283484                   True                               True         False
# 285168                  False                               True         False
# 281602                   True                               True         False
# 285431                  False                               True          True
# 285630                  False                               True          True
#
# [134529 rows x 3 columns]

# %%
#Bondora1["ReportAsOfEOD"] = pd.to_datetime(Bondora1["ReportAsOfEOD"], format='%Y-%m-%d')
#Bondora1["BiddingStartedOn"] = pd.to_datetime(Bondora1["BiddingStartedOn"], format='%Y-%m-%d')
#Bondora1["BidsPortfolioManager"] = pd.to_datetime(Bondora1["BidsPortfolioManager"], format='%Y-%m-%d')

# %%
#Bondora1.dtypes

# %%
features_categorical_data= list(categorical_data.columns)
features_booleen_data= list(booleen_data.columns)

# %%
categorical_data =categorical_data.fillna("unknown")

# %%
date_type= categorical_data["BiddingStartedOn"].astype('datetime64[ns]') 
categorical_data= categorical_data.drop(['BiddingStartedOn'],axis=1)

# %%
#result = Bondora1["NewCreditCustomer"].astype(int)
#result1 = Bondora1["ActiveScheduleFirstPaymentReached"].astype(int)
#result2 = Bondora1["Restructured"].astype(int)
#Bondora1["NewCreditCustomer"] = result
#Bondora1["ActiveScheduleFirstPaymentReached"] = result1
#Bondora1["Restructured"] = result2

#Bondora1

# %%
#Bondora1["Status"] = Bondora1["Status"].astype('category')

# %%
#Bondora1.dtypes

# %% [markdown]
# ## Heatmap

# %%
# plotting the heatmap
#ax = sns.heatmap(Bondora1, vmin=0, vmax=1)
#plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
categorical_a = np.array(categorical_data).reshape(-1) 
booleen_a = np.array(booleen_data).reshape(-1)

# %%
Encoder_1= LabelEncoder()
Encoder_2= LabelEncoder()

# %%
categorical_enc= Encoder_1.fit_transform(categorical_a)
booleen_enc= Encoder_2.fit_transform(booleen_a)

# %%
categorical_enc.shape
# Out:
# (1614348,)

# %%
booleen_enc.shape
# Out:
# (403587,)

# %%
categorical_enc = pd.DataFrame(categorical_enc.reshape(1614348,int(categorical_enc.shape[0]/1614348)))
booleen_enc = pd.DataFrame(booleen_enc.reshape(403587 ,int(booleen_enc.shape[0]/403587 )))

# %%
len(features_categorical_data)
# Out:
# 13

# %%
booleen_enc
# Out:
#         0
# 0       1
# 1       1
# 2       0
# 3       0
# 4       1
# ...    ..
# 403582  1
# 403583  1
# 403584  0
# 403585  1
# 403586  1
#
# [403587 rows x 1 columns]

# %%
categorical_enc.columns = features_categorical_data 
booleen_enc.columns = features_booleen_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_17/3678488367.py in <module>
# ----> 1 categorical_enc.columns= features_categorical_data
#       2 booleen_enc.columns= features_booleen_data
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# /opt/conda/lib/python3.7/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     214     def set_axis(self, axis: int, new_labels: Index) -> None:
#     215         # Caller is responsible for ensuring we have an Index object.
# --> 216         self._validate_set_axis(axis, new_labels)
#     217         self.axes[axis] = new_labels
#     218
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      56         elif new_len != old_len:
#      57             raise ValueError(
# ---> 58                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      59                 f"values have {new_len} elements"
#      60             )
#
# ValueError: Length mismatch: Expected axis has 1 elements, new values have 13 elements

# %%
object_data = pd.concat([categorical_enc,booleen_enc], axis=1)

# %%
object_data

# %% [markdown]
# ### Exploration for Numerical data

# %%
from sklearn.impute import SimpleImputer

# %%
Bondora1

# %% [markdown]
# ### Fill the object data that have less then 90% null

# %%
names_num = Bondora1.columns
imp_median = SimpleImputer(missing_values=np.nan, strategy='median') 
imp_median.fit(np.array(Bondora1))
imp_data= imp_median.transform(Bondora1)
Bondora1= pd.DataFrame(imp_data)
Bondora1.columns= names_num

# %%
Bondora1

# %%
Bondora1.hist(figsize=(20,20))

# %%
Bondora1.describe().transpose()
# Out:
#                                            count         mean           std  \
# BidsPortfolioManager                    134529.0   966.452876   1355.686016
# BidsApi                                 134529.0    29.111664    150.159148
# BidsManual                              134529.0   559.332590    750.360512
# ApplicationSignedHour                   134529.0    13.374640      4.992375
# ApplicationSignedWeekday                134529.0     3.907908      1.726192
# LanguageCode                            134529.0     2.827874      1.959802
# Age                                     134529.0    40.819295     12.348693
# AppliedAmount                           134529.0  2727.947540   2374.439168
# Amount                                  134529.0  2543.872472   2170.128183
# Interest                                134529.0    35.889583     26.288644
# LoanDuration                            134529.0    46.151573     15.202688
# UseOfLoan                               134529.0     0.343026      3.311925
# IncomeFromPrincipalEmployer             134529.0   437.143384   1786.569939
# IncomeFromPension                       134529.0    18.802698    150.849487
# IncomeFromFamilyAllowance               134529.0     5.682848     38.385899
# IncomeFromSocialWelfare                 134529.0     2.390005     36.791193
# IncomeFromLeavePay                      134529.0     3.253239     77.523767
# IncomeFromChildSupport                  134529.0     2.359142     28.459953
# IncomeOther                             134529.0    43.112825    459.081430
# IncomeTotal                             134529.0  1724.150015   4970.165757
# ExistingLiabilities                     134529.0     3.181797      3.424242
# LiabilitiesTotal                        134529.0   562.027010  33831.634630
# RefinanceLiabilities                    134529.0     0.187313      0.896455
# MonthlyPaymentDay                       134529.0    11.143188      7.044104
# PrincipalPaymentsMade                   134529.0   761.476162   1371.557801
# InterestAndPenaltyPaymentsMade          134529.0   488.397102    827.805133
# PrincipalBalance                        134529.0  1769.281104   2030.546309
# InterestAndPenaltyBalance               134529.0   701.567107   2514.595572
# NoOfPreviousLoansBeforeLoan             134529.0     1.487620      2.396148
# AmountOfPreviousLoansBeforeLoan         134529.0  2868.652401   4507.046575
# PreviousEarlyRepaymentsCountBeforeLoan  134529.0     0.069903      0.359461
#
#                                             min     25%        50%      75%  \
# BidsPortfolioManager                     0.0000  155.00   465.0000  1218.00
# BidsApi                                  0.0000    0.00     0.0000     5.00
# BidsManual                               0.0000   96.00   317.0000   729.00
# ApplicationSignedHour                    0.0000   10.00    13.0000    17.00
# ApplicationSignedWeekday                 1.0000    2.00     4.0000     5.00
# LanguageCode                             1.0000    1.00     3.0000     4.00
# Age                                      0.0000   31.00    40.0000    50.00
# AppliedAmount                           31.9558  800.00  2125.0000  4145.00
# Amount                                   6.3900  744.00  2125.0000  3600.00
# Interest                                 3.0000   20.00    30.9300    40.40
# LoanDuration                             1.0000   36.00    48.0000    60.00
# UseOfLoan                               -1.0000   -1.00    -1.0000     0.00
# IncomeFromPrincipalEmployer              0.0000    0.00     0.0000   326.00
# IncomeFromPension                        0.0000    0.00     0.0000     0.00
# IncomeFromFamilyAllowance                0.0000    0.00     0.0000     0.00
# IncomeFromSocialWelfare                  0.0000    0.00     0.0000     0.00
# IncomeFromLeavePay                       0.0000    0.00     0.0000     0.00
# IncomeFromChildSupport                   0.0000    0.00     0.0000     0.00
# IncomeOther                              0.0000    0.00     0.0000     0.00
# IncomeTotal                              0.0000  857.00  1250.0000  1900.00
# ExistingLiabilities                      0.0000    1.00     2.0000     5.00
# LiabilitiesTotal                         0.0000   73.54   316.3800   620.58
# RefinanceLiabilities                     0.0000    0.00     0.0000     0.00
# MonthlyPaymentDay                        0.0000    5.00    10.0000    15.00
# PrincipalPaymentsMade                    0.0000   50.87   208.1000   766.41
# InterestAndPenaltyPaymentsMade           0.0000   44.93   181.2100   568.53
# PrincipalBalance                       -34.2000  212.82  1061.9900  2636.33
# InterestAndPenaltyBalance               -2.6600    0.00     0.0000   202.90
# NoOfPreviousLoansBeforeLoan              0.0000    0.00     1.0000     2.00
# AmountOfPreviousLoansBeforeLoan          0.0000    0.00   396.3541  4250.00
# PreviousEarlyRepaymentsCountBeforeLoan   0.0000    0.00     0.0000     0.00
#
#                                                 max
# BidsPortfolioManager                       10625.00
# BidsApi                                     7570.00
# BidsManual                                 10630.00
# ApplicationSignedHour                         23.00
# ApplicationSignedWeekday                       7.00
# LanguageCode                                  22.00
# Age                                           77.00
# AppliedAmount                              10632.00
# Amount                                     10632.00
# Interest                                     264.31
# LoanDuration                                  60.00
# UseOfLoan                                    110.00
# IncomeFromPrincipalEmployer               228400.00
# IncomeFromPension                           5038.00
# IncomeFromFamilyAllowance                   2006.00
# IncomeFromSocialWelfare                     4551.00
# IncomeFromLeavePay                         21300.00
# IncomeFromChildSupport                      2500.00
# IncomeOther                                50000.00
# IncomeTotal                              1012019.00
# ExistingLiabilities                           40.00
# LiabilitiesTotal                        12400000.00
# RefinanceLiabilities                          23.00
# MonthlyPaymentDay                             28.00
# PrincipalPaymentsMade                      10632.00
# InterestAndPenaltyPaymentsMade             16873.00
# PrincipalBalance                           10632.00
# InterestAndPenaltyBalance                  64494.77
# NoOfPreviousLoansBeforeLoan                   25.00
# AmountOfPreviousLoansBeforeLoan            53762.00
# PreviousEarlyRepaymentsCountBeforeLoan        11.00

# %% [markdown]
# ### Preprocessing for Numerical data

# %%
# we'll be using z-score for normalization
def z_score_normalizer(X): 
    m = X.shape[0]
    n=1
    for i in range(n):
        X = (X - X.mean(axis=0))/X.std(axis=0) 
    return X

# %%
Bondora1 = z_score_normalizer(Bondora1)

# %%
object_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_17/1331014821.py in <module>
# ----> 1 object_data
#
# NameError: name 'object_data' is not defined

# %% [markdown]
# ### Target Selection

# %%
Y= object_data['Status']
object_data = object_data.drop(['Status'],axis=1) 
Y=encoder_1.inverse_transform(Y)
Y= pd.DataFrame(Y, columns=['Status']) 
Y.Status.unique()
